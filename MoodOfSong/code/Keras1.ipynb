# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pickle
import numpy as np


from sklearn.preprocessing import MinMaxScaler

# %% [raw]
# Pre_Processing data

# %%
# Load training data set from CSV file
training_data_df = pd.read_csv('../../dataset/training/train_lyrics_1000.csv')
training_data_df
# Out:
#                       file                             artist  \
# 0    TRAAAAW128F429D538.h5                             Casual
# 1    TRAAAEF128F4273421.h5                           Adam Ant
# 2    TRAAAFD128F92F423A.h5                                Gob
# 3    TRAABJV128F1460C49.h5                      Lionel Richie
# 4    TRAABLR128F423B7E3.h5                         Blue Rodeo
# 5    TRAABVM128F92CA9DC.h5                              Tesla
# 6    TRAACER128F4290F96.h5          The Dillinger Escape Plan
# 7    TRAACFV128F935E50B.h5                       SUE THOMPSON
# 8    TRAACHN128F1489601.h5                     Five Bolt Main
# 9    TRAACNS128F14A2DF5.h5                        Willie Bobo
# 10   TRAACQT128F9331780.h5                        John Wesley
# 11   TRAACTB12903CAAF15.h5                   Billie Jo Spears
# 12   TRAADLN128F14832E9.h5                 The Rolling Stones
# 13   TRAADNA128F9331246.h5                 Stevie Ray Vaughan
# ...

# %% [raw]
# # Load testing data set from CSV file
# # test_data_df =pd.read_csv('../../dataset/training/train_lyrics_1000.csv')

# %%
# Data needs to be scaled to a small range like 0 to 1 for the neural
# network to work well.
scaler = MinMaxScaler(feature_range=(0, 1))


X_train = training_data_df['lyrics'].values 

y_train = training_data_df['mood'].values

# Label Encoder
le = LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)


# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
# scaled_testing = scaler.transform(test_data_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-3b290e0f27a8> in <module>
#      16
#      17 # Scale both the training inputs and outputs
# ---> 18 scaled_training = scaler.fit_transform(training_data_df)
#      19 # scaled_testing = scaler.transform(test_data_df)
#
# /anaconda2/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# /anaconda2/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     306         # Reset internal state before fitting
#     307         self._reset()
# --> 308         return self.partial_fit(X, y)
# ...

# %%
# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))

# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("sales_data_training_scaled.csv", index=False)
scaled_testing_df.to_csv("sales_data_testing_scaled.csv", index=False)
